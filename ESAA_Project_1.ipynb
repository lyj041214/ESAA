# %% [markdown]
# <a href="https://colab.research.google.com/github/lyj041214/ESAA/blob/main/ESAA_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("movies_train.csv")

# %%
data.head()
# Out:
#        title   distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3   나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4       불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1      1161602.50             2        387          3      7072501
# 2       220775.25             4        343          4      6959083
# 3        23894.00             2         20          6       217866
# 4            1.00             1        251          2       483387

# %% [markdown]
# # 5. 배급사별 평균 관객 수 (바 그래프)

# %% [markdown]
# ## bar chart를 통해 평균 관객 수 알아보기

# %%
# 5. 배급사별 평균 관객 수 (바 그래프)

# 배급사별 평균 관객 수 계산
avg_box_off_num_by_distributor = data.groupby("distributor")["box_off_num"].mean().sort_values(ascending=False)

# 그래프 그리기
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_box_off_num_by_distributor.index, y=avg_box_off_num_by_distributor.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor")
plt.ylabel("avg_box_off_num")
plt.title("avg_box_off_num_by_distributor")
plt.show()
# Out:
# <ipython-input-6-656d67684c5d>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_box_off_num_by_distributor.index, y=avg_box_off_num_by_distributor.values, palette="viridis")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# X의 범위가 너무 커서 tail과 head 50개씩 따로 살펴보기

# 배급사별 평균 관객 수 계산
avg_audience_by_distributor = data.groupby("distributor")["box_off_num"].mean().sort_values(ascending=False)

print(avg_audience_by_distributor.tail(50))
print('\n')
print(avg_audience_by_distributor.head(50))
# Out:
# distributor
# 드림로드               1391.500000
# 키노엔터테인먼트           1351.000000
# 노바엔터테인먼트           1315.500000
# 서울독립영화제            1287.500000
# 드림팩트 엔터테인먼트        1243.333333
# (주)노버스엔터테인먼트       1217.000000
# 퍼스트런               1132.000000
# (주)콘텐츠 윙           1079.000000
# M2픽처스              1045.000000
# (주) 케이알씨지          1027.285714
# (주)드림팩트엔터테인먼트      1008.000000
# (주)피터팬픽쳐스           961.000000
# (주)고앤고 필름           948.000000
# 마운틴 픽처스             868.666667
# (주)두타연              868.000000
# (주)패뷸러스             862.000000
# 이모션 픽처스             861.666667
# 아방가르드 필름            831.000000
# (주)랠리버튼             820.000000
# 동국대학교 충무로영상제작센터     742.000000
# 팜코리아미디어             721.000000
# 제나두 엔터테인먼트          678.000000
# 두 엔터테인먼트            647.000000
# 스폰지이엔티              614.000000
# (주) 액티버스엔터테인먼트      610.000000
# 하준사                 600.000000
# 쟈비스미디어              588.000000
# 마법사필름               555.000000
# 디마엔터테인먼트            484.000000
# ...

# %%
#head
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_box_off_num_by_distributor.head(50).index, y=avg_box_off_num_by_distributor.head(50).values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor")
plt.ylabel("avg_box_off_num")
plt.title("avg_box_off_num_by_distributor")
plt.show()
# Out:
# <ipython-input-8-68ded152f7b2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_box_off_num_by_distributor.head(50).index, y=avg_box_off_num_by_distributor.head(50).values, palette="viridis")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#tail
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_box_off_num_by_distributor.tail(50).index, y=avg_box_off_num_by_distributor.tail(50).values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor")
plt.ylabel("avg_box_off_num")
plt.title("avg_box_off_num_by_distributor")
plt.show()
# Out:
# <ipython-input-9-1f548e17f98b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_box_off_num_by_distributor.tail(50).index, y=avg_box_off_num_by_distributor.tail(50).values, palette="viridis")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47548 (\N{HANGUL SYLLABLE RIM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 배급사별 평균 관객 수 계산
avg_box_off_num_by_distributor = data.groupby("distributor")["box_off_num"].mean().sort_values(ascending=False)

# 배급사별로 boxplot 그리기 (평균 관객수가 높은 순서대로)
plt.figure(figsize=(12, 6))
sns.boxplot(x="distributor", y="box_off_num", data=data, order=avg_box_off_num_by_distributor.index, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor")
plt.ylabel("box_off_num")
plt.title("Boxplot of box_off_num by distributor")
plt.show()
# Out:
# <ipython-input-10-12fcd5d65b7c>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="distributor", y="box_off_num", data=data, order=avg_box_off_num_by_distributor.index, palette="viridis")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# bar chart로 배급사 별 평균 관객 수는 알 수 있지만 이상치의 존재 유무와 전체 자료의 분포를 파악할 수 없음.
# ## boxplot을 통해 distributor 범주 별 자료 분포 알아보기

# %%
# head(50)
top_50_distributors = avg_box_off_num_by_distributor.head(50).index

# 상위 50개 배급사의 boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="distributor", y="box_off_num", data=data[data["distributor"].isin(top_50_distributors)],
            order=top_50_distributors, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor (Top 50)")
plt.ylabel("box_off_num")
plt.title("Boxplot of box_off_num for Top 50 distributors")
plt.show()
# Out:
# <ipython-input-11-6012ffa26369>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="distributor", y="box_off_num", data=data[data["distributor"].isin(top_50_distributors)],
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# tail(50)
bottom_50_distributors = avg_box_off_num_by_distributor.tail(50).index

# 하위 50개 배급사의 boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="distributor", y="box_off_num", data=data[data["distributor"].isin(bottom_50_distributors)],
            order=bottom_50_distributors, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("distributor (Bottom 50)")
plt.ylabel("box_off_num")
plt.title("Boxplot of box_off_num for Bottom 50 distributors")
plt.show()
# Out:
# <ipython-input-12-90674253a102>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="distributor", y="box_off_num", data=data[data["distributor"].isin(bottom_50_distributors)],
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47548 (\N{HANGUL SYLLABLE RIM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # 6. 상영 시간 vs. 관객 수 관계 (산점도)

# %%
# 6. 상영 시간 vs. 관객 수 관계 (산점도)

# 산점도 그리기
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data["time"], y=data["box_off_num"], alpha=0.5)

# 그래프 설정
plt.xlabel("time")
plt.ylabel("box_off_num")
plt.title("time vs box_off_num")
plt.grid(True)
plt.show()

# %% [markdown]
# 시각화 결과 상영 시간이 120분-140분 범주에서 관객 수가 가장 많음을 알 수 있다.

# %%
# 로그 스케일을 적용: box_off_num의 분포가 너무 넓어서 쏠려보이기 때문

# 관객 수가 0 이상인 값만 필터링 (로그 변환을 위해)
data_p = data[data["box_off_num"] > 0]

# 그래프 그리기
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_p["time"], y=np.log1p(data_p["box_off_num"]), alpha=0.5)

# 그래프 설정
plt.xlabel("time")
plt.ylabel("box_off_num_log")
plt.title("time vs box_off_num")
plt.grid(True)
plt.show()

# %% [markdown]
# 로그 변환을 했지만 유의미한 결과 도출을 위해서는 로그 변환 이전이 좋을 것 같음.

# %% [markdown]
# # 장르와 상영 시간, 상영 등급의 관계 알아보기

# %%
# 장르의 목록
data["genre"].unique()
# Out:
# array(['액션', '느와르', '코미디', '다큐멘터리', '뮤지컬', '드라마', '멜로/로맨스', '공포', '서스펜스',
#        '애니메이션', '미스터리', 'SF'], dtype=object)

# %%
# 상영 등급의 목록
data["screening_rat"].unique()
# Out:
# array(['청소년 관람불가', '15세 관람가', '전체 관람가', '12세 관람가'], dtype=object)

# %%
# 상영 등급 정렬 (등급이 높은 순서)
# 원하는 순서 지정
screening_order = ["청소년 관람불가", "15세 관람가", "12세 관람가", "전체 관람가"]

# %%
# 그래프 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(x="genre", y="time", hue="screening_rat", data=data, palette="Set2", hue_order=screening_order)

# 그래프 설정
plt.xticks(rotation=45)
plt.xlabel("genre")
plt.ylabel("time")
plt.title("screening_rat")
plt.legend(title="screening_rat", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45712 (\N{HANGUL SYLLABLE NEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from font(s) DejaVu Sans.
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="genre", y="time", hue="screening_rat", data=data, estimator=np.mean, palette="coolwarm",hue_order=screening_order)

plt.xticks(rotation=45)
plt.xlabel("Genre")
plt.ylabel("Time (minutes)")
plt.title("Average Running Time by Genre (by Screening Rating)")
plt.legend(title="Screening Rating", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49496 (\N{HANGUL SYLLABLE SYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45712 (\N{HANGUL SYLLABLE NEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# 장르별 상영 등급과 상영 시간의 관계는 box plot보다 bar plot으로 나타냈을 때 불필요한 정보가 제거됨. 장르별로 아예 존재하지 않는 상영 등급에 주목하여 장르의 특성 파악하기.

# %%
# 평균 관객 수가 높은 상위 10개 배급사 선택
top_10_distributors = data.groupby("distributor")["box_off_num"].mean().nlargest(10).index

# 해당 배급사만 필터링
filtered_data = data[data["distributor"].isin(top_10_distributors)]

plt.figure(figsize=(12, 6))
sns.scatterplot(x="time", y="box_off_num", hue="distributor", data=filtered_data, alpha=0.7, palette="tab10")

plt.xlabel("time")
plt.ylabel("box_off_num")
plt.title("time vs box_off_num for Top 10 Distributors")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")  # 범례 위치 조정
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
# ...

# %%
# 배급사별 평균 관객 수 계산 후 정렬
avg_box_off_num_by_distributor = data.groupby("distributor")["box_off_num"].mean().sort_values(ascending=False)

# 상위 50개, 하위 50개, 나머지 그룹 분류
top_50_distributors = avg_box_off_num_by_distributor.head(50).index
bottom_50_distributors = avg_box_off_num_by_distributor.tail(50).index

# 새로운 컬럼 추가 (그룹 라벨링)
def classify_distributor(distributor):
    if distributor in top_50_distributors:
        return "Top 50"
    elif distributor in bottom_50_distributors:
        return "Bottom 50"
    else:
        return "Middle"

data["distributor_group"] = data["distributor"].apply(classify_distributor)

# 색상 팔레트 설정 (3가지 그룹)
palette = {"Top 50": "red", "Middle": "blue", "Bottom 50": "green"}

# 산점도 그리기
plt.figure(figsize=(12, 6))
sns.scatterplot(x="time", y="box_off_num", hue="distributor_group", data=data, alpha=0.7, palette=palette)

# 그래프 설정
plt.xlabel("time")
plt.ylabel("box_off_num")
plt.title("time vs box_off_num by Distributor Group")
plt.legend(title="Distributor Group", bbox_to_anchor=(1.05, 1), loc="upper left")  # 범례 위치 조정
plt.grid(True)
plt.show()
